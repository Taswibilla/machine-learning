# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Dataset: [area, bedrooms]
X = np.array([
    [1000, 2],
    [1500, 3],
    [1800, 4],
    [2400, 3],
    [3000, 5]
])

# Output: house price
y = np.array([50, 65, 80, 95, 120])

# Model
model = LinearRegression()

# Train
model.fit(X, y)

# Predict
new_house = np.array([[2000, 3]])
prediction = model.predict(new_house)

print("Prediction:", prediction)
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Prediction: [82.67475728]
# Coefficients: [0.03101942 2.96601942]
# Intercept: 11.737864077669883
